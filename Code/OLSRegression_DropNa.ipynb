# %%
import pandas as pd
df = pd.read_excel("/content/USE_THIS_for_Regression_New.xlsx")
df.head()
# Out:
#    Unnamed: 0  OBJECTID  STATEFP  COUNTYFP  TRACTCE  BLKGRPCE         GEOID  \
# 0           0         1       36         5    17500         2  360050175002
# 1           1         2       36         5    14100         1  360050141001
# 2           2         3       36         5    14500         1  360050145001
# 3           3         4       36         5     7500         2  360050075002
# 4           4         5       36         5    41800         1  360050418001
#
#         NAMELSAD  MTFCC FUNCSTAT  ...  Pct 10 to 19  Pct 20 to 29  \
# 0  Block Group 2  G5030        S  ...          0.00          6.67
# 1  Block Group 1  G5030        S  ...          5.26         27.89
# 2  Block Group 1  G5030        S  ...          6.48          2.63
# 3  Block Group 2  G5030        S  ...          9.15          8.14
# 4  Block Group 1  G5030        S  ...         36.49          7.72
#
#    Pct 30 to 39  Pct 40 to 59  Pct 60 to 89  Pct 90 or More  \
# ...

# %%
df_copy = df.copy()

# %%
dffinal=df_copy.dropna(subset=['Ln Income', 'Ln Housing Value'])

# %%
dffinal.to_excel('dropNa_USE_THIS.xlsx')
